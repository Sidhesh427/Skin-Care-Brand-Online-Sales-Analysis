# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
channel_data=pd.read_csv('assignment_data_channel.csv')

# %%
channel_data.columns=channel_data.columns.str.lower()
channel_data.head()
# Out:
#      id  account_id   channel
# 0  2001          19  FACEBOOK
# 1  2002          18   ADWORDS
# 2  2003          11   ADWORDS
# 3  2004           3    DIRECT
# 4  2005          16    DIRECT

# %%
website_data=pd.read_csv('assignment_data_website.csv')

# %%
website_data.columns=website_data.columns.str.lower()
website_data.head()
# Out:
#      id website
# 0  2001    AMZN
# 1  2002  FLPKRT
# 2  2003  FLPKRT
# 3  2004    AMZN
# 4  2005    AMZN

# %%
sales=pd.read_csv('assignment_data_sales.csv')

# %%
sales.columns=sales.columns.str.lower()
sales.rename(columns={'total quatity sold':'total quantity sold'},inplace=True)
sales.head()
# Out:
#    account_id  total quantity sold  regular quantity sold  total $ sales  \
# 0          19                43609                  30000      2024247.5
# 1          18                55854                  25000      2223485.0
# 2          11                97257                  60000      4324567.5
# 3           3                 5243                   5000       281682.5
# 4          16                11773                   5000       461257.5
#
#     channel
# 0  FACEBOOK
# 1   ADWORDS
# 2   ADWORDS
# 3    DIRECT
# 4    DIRECT

# %%
sales_copy=sales.copy()
sales_copy.head()
# Out:
#    account_id  total quantity sold  regular quantity sold  total $ sales  \
# 0          19                43609                  30000      2024247.5
# 1          18                55854                  25000      2223485.0
# 2          11                97257                  60000      4324567.5
# 3           3                 5243                   5000       281682.5
# 4          16                11773                   5000       461257.5
#
#     channel
# 0  FACEBOOK
# 1   ADWORDS
# 2   ADWORDS
# 3    DIRECT
# 4    DIRECT

# %%
sales_copy['promo_qty_sold']=sales_copy['total quantity sold']-sales_copy['regular quantity sold']
sales_copy['promo_sales']=sales_copy['promo_qty_sold']*27.5
sales_copy['reg_sales']=sales_copy['total $ sales']-sales_copy['promo_sales']

# %%
sales_copy
# Out:
#     account_id  total quantity sold  regular quantity sold  total $ sales  \
# 0           19                43609                  30000      2024247.5
# 1           18                55854                  25000      2223485.0
# 2           11                97257                  60000      4324567.5
# 3            3                 5243                   5000       281682.5
# 4           16                11773                   5000       461257.5
# 5            1                33783                  20000      1479032.5
# 6           20                82189                  35000      3222697.5
# 7            2                95613                  40000      3729357.5
# 8           12                41848                  35000      2113320.0
# 9           10                24173                  15000      1077257.5
# 10          13                49789                  30000      2194197.5
# 11          15                71701                  48000      3291777.5
# 12           9                97747                  56000      4228042.5
# 13          14                53643                  42000      2630182.5
# 14          17                34444                  20000      1497210.0
# 15           8                69535                  38000      2957212.5
# 16           7                25157                  14000      1076817.5
# 17           4                71355                  40000      3062262.5
# 18           5                96524                  55000      4166910.0
# 19           6                73250                  40000      3114375.0
#
#      channel  promo_qty_sold  promo_sales  reg_sales
# 0   FACEBOOK           13609     374247.5  1650000.0
# 1    ADWORDS           30854     848485.0  1375000.0
# 2    ADWORDS           37257    1024567.5  3300000.0
# 3     DIRECT             243       6682.5   275000.0
# 4     DIRECT            6773     186257.5   275000.0
# 5    ADWORDS           13783     379032.5  1100000.0
# 6     DIRECT           47189    1297697.5  1925000.0
# 7    ADWORDS           55613    1529357.5  2200000.0
# 8     DIRECT            6848     188320.0  1925000.0
# 9    TWITTER            9173     252257.5   825000.0
# 10   TWITTER           19789     544197.5  1650000.0
# 11   TWITTER           23701     651777.5  2640000.0
# 12    DIRECT           41747    1148042.5  3080000.0
# 13   TWITTER           11643     320182.5  2310000.0
# 14    DIRECT           14444     397210.0  1100000.0
# 15   TWITTER           31535     867212.5  2090000.0
# 16    DIRECT           11157     306817.5   770000.0
# 17   TWITTER           31355     862262.5  2200000.0
# 18  FACEBOOK           41524    1141910.0  3025000.0
# 19  FACEBOOK           33250     914375.0  2200000.0

# %%
chnl_grp_sales=sales_copy.groupby('channel',as_index=False)['total $ sales','promo_sales','reg_sales'].sum()
pd.DataFrame(chnl_grp_sales)
# Out:
#     channel  total $ sales  promo_sales   reg_sales
# 0   ADWORDS     11756442.5    3781442.5   7975000.0
# 1    DIRECT     12881027.5    3531027.5   9350000.0
# 2  FACEBOOK      9305532.5    2430532.5   6875000.0
# 3   TWITTER     15212890.0    3497890.0  11715000.0

# %%
# %matplotlib inline
from matplotlib.ticker import FuncFormatter
def millions(x, pos):
    'The two args are the value and tick position'
    return '$%1.1fM' % (x * 1e-6)
formatter = FuncFormatter(millions)

fig,ax= plt.subplots(figsize=(9,10))
fig.patch.set_facecolor('white')
plt.style.use('fivethirtyeight')
plt.rcParams['text.color'] = '#000000'
plt.rcParams['axes.labelcolor']= '#000000'
plt.rcParams['xtick.color'] = '#000000'
plt.rcParams['ytick.color'] = '#000000'
plt.rcParams['font.size']=14
colors=['#80BD9E','#F98866','#336B87','#A1D6E2']
width=0.4
pos=np.arange(len(chnl_grp_sales['channel']))
bar1=ax.bar(pos,chnl_grp_sales['total $ sales'],color=colors,width=width)
ax.set_xticks(pos)
ax.set_xticklabels(list(chnl_grp_sales['channel']))
ax.yaxis.set_major_formatter(formatter)
ax.set_title('CHANNEL SALES',fontsize=17)
plt.show()
plt.savefig('channel_sales.png')

# %%
id_join=pd.merge(sales_copy,channel_data,on=['account_id','channel'])
id_join
# Out:
#     account_id  total quantity sold  regular quantity sold  total $ sales  \
# 0           19                43609                  30000      2024247.5
# 1           18                55854                  25000      2223485.0
# 2           11                97257                  60000      4324567.5
# 3            3                 5243                   5000       281682.5
# 4           16                11773                   5000       461257.5
# 5            1                33783                  20000      1479032.5
# 6           20                82189                  35000      3222697.5
# 7            2                95613                  40000      3729357.5
# 8           12                41848                  35000      2113320.0
# 9           10                24173                  15000      1077257.5
# 10          13                49789                  30000      2194197.5
# 11          15                71701                  48000      3291777.5
# 12           9                97747                  56000      4228042.5
# 13          14                53643                  42000      2630182.5
# 14          17                34444                  20000      1497210.0
# 15           8                69535                  38000      2957212.5
# 16           7                25157                  14000      1076817.5
# 17           4                71355                  40000      3062262.5
# 18           5                96524                  55000      4166910.0
# 19           6                73250                  40000      3114375.0
#
#      channel  promo_qty_sold  promo_sales  reg_sales    id
# 0   FACEBOOK           13609     374247.5  1650000.0  2001
# 1    ADWORDS           30854     848485.0  1375000.0  2002
# 2    ADWORDS           37257    1024567.5  3300000.0  2003
# 3     DIRECT             243       6682.5   275000.0  2004
# 4     DIRECT            6773     186257.5   275000.0  2005
# 5    ADWORDS           13783     379032.5  1100000.0  2006
# 6     DIRECT           47189    1297697.5  1925000.0  2007
# 7    ADWORDS           55613    1529357.5  2200000.0  2008
# 8     DIRECT            6848     188320.0  1925000.0  2009
# 9    TWITTER            9173     252257.5   825000.0  2010
# 10   TWITTER           19789     544197.5  1650000.0  2011
# 11   TWITTER           23701     651777.5  2640000.0  2012
# 12    DIRECT           41747    1148042.5  3080000.0  2013
# 13   TWITTER           11643     320182.5  2310000.0  2014
# 14    DIRECT           14444     397210.0  1100000.0  2015
# 15   TWITTER           31535     867212.5  2090000.0  2016
# 16    DIRECT           11157     306817.5   770000.0  2017
# 17   TWITTER           31355     862262.5  2200000.0  2018
# 18  FACEBOOK           41524    1141910.0  3025000.0  2019
# 19  FACEBOOK           33250     914375.0  2200000.0  2020

# %%
df=pd.merge(id_join,website_data,on='id')

# %%
df
# Out:
#     account_id  total quantity sold  regular quantity sold  total $ sales  \
# 0           19                43609                  30000      2024247.5
# 1           18                55854                  25000      2223485.0
# 2           11                97257                  60000      4324567.5
# 3            3                 5243                   5000       281682.5
# 4           16                11773                   5000       461257.5
# 5            1                33783                  20000      1479032.5
# 6           20                82189                  35000      3222697.5
# 7            2                95613                  40000      3729357.5
# 8           12                41848                  35000      2113320.0
# 9           10                24173                  15000      1077257.5
# 10          13                49789                  30000      2194197.5
# 11          15                71701                  48000      3291777.5
# 12           9                97747                  56000      4228042.5
# 13          14                53643                  42000      2630182.5
# 14          17                34444                  20000      1497210.0
# 15           8                69535                  38000      2957212.5
# 16           7                25157                  14000      1076817.5
# 17           4                71355                  40000      3062262.5
# 18           5                96524                  55000      4166910.0
# 19           6                73250                  40000      3114375.0
#
#      channel  promo_qty_sold  promo_sales  reg_sales    id website
# 0   FACEBOOK           13609     374247.5  1650000.0  2001    AMZN
# 1    ADWORDS           30854     848485.0  1375000.0  2002  FLPKRT
# 2    ADWORDS           37257    1024567.5  3300000.0  2003  FLPKRT
# 3     DIRECT             243       6682.5   275000.0  2004    AMZN
# 4     DIRECT            6773     186257.5   275000.0  2005    AMZN
# 5    ADWORDS           13783     379032.5  1100000.0  2006  FLPKRT
# 6     DIRECT           47189    1297697.5  1925000.0  2007    AMZN
# 7    ADWORDS           55613    1529357.5  2200000.0  2008  FLPKRT
# 8     DIRECT            6848     188320.0  1925000.0  2009    AMZN
# 9    TWITTER            9173     252257.5   825000.0  2010  FLPKRT
# 10   TWITTER           19789     544197.5  1650000.0  2011   SNPDL
# 11   TWITTER           23701     651777.5  2640000.0  2012   SNPDL
# 12    DIRECT           41747    1148042.5  3080000.0  2013    AMZN
# 13   TWITTER           11643     320182.5  2310000.0  2014    AMZN
# 14    DIRECT           14444     397210.0  1100000.0  2015    AMZN
# 15   TWITTER           31535     867212.5  2090000.0  2016   SNPDL
# 16    DIRECT           11157     306817.5   770000.0  2017    AMZN
# 17   TWITTER           31355     862262.5  2200000.0  2018  FLPKRT
# 18  FACEBOOK           41524    1141910.0  3025000.0  2019    AMZN
# 19  FACEBOOK           33250     914375.0  2200000.0  2020   SNPDL

# %%
dataset=df.groupby('website',as_index=False)['promo_sales','reg_sales'].sum()

# %%
dataset
# Out:
#   website  promo_sales   reg_sales
# 0    AMZN    5367367.5  16335000.0
# 1  FLPKRT    4895962.5  11000000.0
# 2   SNPDL    2977562.5   8580000.0

# %%
websites=['Amazon','Flipkart','Snapdeal']
pos=np.arange(len(websites))
promo_sales_total=list(dataset['promo_sales'])
reg_sales_total=list(dataset['reg_sales'])
bar_width=0.30
lables=['promo_sales_total','reg_sales_total']
fig, ax=plt.subplots(figsize=(15,8))
fig.patch.set_facecolor('white')
plt.style.use('fivethirtyeight')
bar1=ax.bar(pos-bar_width/2,promo_sales_total, bar_width,label='promo_sales_total',color='#9A9EAB')
bar2=ax.bar(pos+bar_width/2,reg_sales_total, bar_width, label='reg_sales_total',color='#EC96A4')
ax.set_xticks(pos)
ax.set_xticklabels(websites)
ax.yaxis.set_major_formatter(formatter)
ax.set_title('PROMO vs NON-PROMO SALES ACROSS WEBSITES',fontsize=20)
ax.legend(fontsize=18,ncol=2)
plt.show()

# %%
promo_sales_total=dataset['promo_sales']

# %%
dataset_channel=df.groupby('channel',as_index=False)['promo_sales','reg_sales'].sum()

# %%
dataset_channel
# Out:
#     channel  promo_sales   reg_sales
# 0   ADWORDS    3781442.5   7975000.0
# 1    DIRECT    3531027.5   9350000.0
# 2  FACEBOOK    2430532.5   6875000.0
# 3   TWITTER    3497890.0  11715000.0

# %%
channels=list(dataset_channel['channel'])
pos=np.arange(len(channels))
promo_sales_total=list(dataset_channel['promo_sales'])
reg_sales_total=list(dataset_channel['reg_sales'])
bar_width=0.30
fig, ax=plt.subplots(figsize=(15,8))
fig.patch.set_facecolor('white')
plt.style.use('fivethirtyeight')
bar1=ax.bar(pos-bar_width/2,promo_sales_total, bar_width, label='promo_sales_total',color='#5D535E')
bar2=ax.bar(pos+bar_width/2,reg_sales_total, bar_width, label='reg_sales_total',color='#DFE166')
ax.set_xticks(pos)
ax.set_xticklabels(channels)
ax.yaxis.set_major_formatter(formatter)
ax.set_title('PROMO vs NON-PROMO SALES ACROSS CHANNELS')
ax.legend(fontsize=17,ncol=2)
plt.show()

# %%
dataset['promo_sales_perct']=round((dataset['promo_sales']/dataset['promo_sales'].sum())*100,0)
dataset['reg_sales_perct']=round((dataset['reg_sales']/dataset['reg_sales'].sum())*100,0)

# %%
dataset
# Out:
#   website  promo_sales   reg_sales  promo_sales_perct  reg_sales_perct
# 0    AMZN    5367367.5  16335000.0               41.0             45.0
# 1  FLPKRT    4895962.5  11000000.0               37.0             31.0
# 2   SNPDL    2977562.5   8580000.0               22.0             24.0

# %%
fig=plt.figure()
fig.patch.set_facecolor('white')
labels=['Amazon','Flipkart','Snapdeal']
colors=['#FFDB5C','#4897D8','#FA6E59']
explode=[0.2,0,0]
axes1=fig.add_axes([0.1,0.1,0.5,0.5])
axes1.pie(dataset['promo_sales_perct'], radius=2.5, explode=explode, shadow=True, 
          colors=colors, autopct='%1.1f%%', textprops={'fontsize':15,'fontweight':'bold'})
axes1.set_title('PROMO SALES', loc='center', y=1.8, fontsize=17, fontweight='bold')

axes2=fig.add_axes([1,0.1,0.5,0.5])
axes2.pie(dataset['reg_sales_perct'], radius=2.5, explode=explode, shadow=True, 
          colors=colors, autopct='%1.1f%%',textprops={'fontsize':15,'fontweight':'bold'})
axes2.set_title('REGULAR SALES', loc='center', y=1.8,fontsize=17, fontweight='bold')
axes1.legend(labels,title='Websites', loc='upper right', bbox_to_anchor=(2.1,-1.7,1.0,1.0),
             ncol=3, fontsize=14)
plt.show()

# %%
dataset_channel['promo_sales_perct']=round((dataset_channel['promo_sales']/dataset_channel['promo_sales'].sum())*100,0)
dataset_channel['reg_sales_perct']=round((dataset_channel['reg_sales']/dataset_channel['reg_sales'].sum())*100,0)
dataset_channel
# Out:
#     channel  promo_sales   reg_sales  promo_sales_perct  reg_sales_perct
# 0   ADWORDS    3781442.5   7975000.0               29.0             22.0
# 1    DIRECT    3531027.5   9350000.0               27.0             26.0
# 2  FACEBOOK    2430532.5   6875000.0               18.0             19.0
# 3   TWITTER    3497890.0  11715000.0               26.0             33.0

# %%
fig=plt.figure()
fig.patch.set_facecolor('white')
labels=['AdWords','Direct','Facebook','Twitter']
colors=['#68A225','#BCBABE','#1995AD','#A1D6E2']
explode=[0.2,0,0,0]
axes1=fig.add_axes([0.1,0.1,0.5,0.5])
axes1.pie(dataset_channel['promo_sales_perct'], radius=2.5, explode=explode, shadow=True, 
          colors=colors, autopct='%1.1f%%', textprops={'fontsize':15,'fontweight':'bold'})
axes1.set_title('PROMO SALES', loc='center', y=1.8, fontsize=17, fontweight='bold')


axes2=fig.add_axes([1.0,0.1,0.5,0.5])
axes2.pie(dataset_channel['reg_sales_perct'], radius=2.5, explode=[0,0,0,0.2], shadow=True, 
          colors=colors, autopct='%1.1f%%',textprops={'fontsize':15,'fontweight':'bold'})
axes2.set_title('REGULAR SALES', loc='center', y=1.8,fontsize=17, fontweight='bold')
axes1.legend(labels,title='Channels', loc='lower right', bbox_to_anchor=(2.4,-1,1.0,1.0),
             ncol=4, fontsize=14)
plt.show()
